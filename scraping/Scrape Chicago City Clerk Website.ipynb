# %% [markdown]
# # Chicago City Council Voting Records
# ### 2 April 2017 (v1)
# ### 8 April 2017 (v2)
#
# As part of the Data for Democracy "Chicago Lobbyists" project, I've scraped historical voting records for each of the city's Alder-persons.
#
# The outputs of this notebook are at https://data.world/stephen-hoover/chicago-city-council-votes .
#
# You can find the Chicago Lobbyists project at https://data.world/lilianhj/chicago-lobbyists .
#
# To learn more about Data for Democracy, go to https://github.com/Data4Democracy/read-this-first .

# %%
from collections import Counter
from glob import glob
from itertools import chain
import os
import re
import string
import subprocess
import sys
import tempfile
import urllib

import bs4
import pandas as pd

from typing import Dict, List, Tuple

# %%
WORKING_DIR = os.path.join(os.path.expanduser('~'), 'projects', 'd4d', 'chicago-lobbyists')

# %% [markdown]
# # Download Data
#
# Chicago city council voting records exist in the form of pdfs on the city clerk's website. The votes all seem to be in pdfs titled "Attendence and Divided Roll Call Vote", so download only those pdfs. The website is paginated (as of April 2017). We can find the number of pages by inspecting the "Go to last page" link.
#
# The table on the city clerk's website includes a meeting date with each download link. Use that to create the file name.

# %%
base = 'http://www.chicityclerk.com/'
suffix = 'legislation-records/journals-and-reports/council-meeting-reports'
page_query = '?field_publish_date_value[value]&page={num}'
resp = urllib.request.urlopen(base + suffix + page_query.format(num=0))
soup = bs4.BeautifulSoup(resp.read(), "html5lib")

# %%
last_page_link = [l for l in soup.find_all('a') if l.attrs.get('title') == 'Go to last page'][0].attrs['href']
print(last_page_link)
last_page = int(last_page_link.split('=')[-1])
print(last_page)
# Out:
# /legislation-records/journals-and-reports/council-meeting-reports?field_publish_date_value[value]=&page=27
# 27

# %%
download_links = []
for page_num in range(last_page + 1):
    resp = urllib.request.urlopen(base + suffix + page_query.format(num=page_num))
    soup = bs4.BeautifulSoup(resp.read(), "html5lib")
    for link in soup.find_all('a', string='Download'):
        link_info = {'title': list(link.parent.parent.parent.children)[3].text.strip(),
                     'date': list(link.parent.parent.parent.children)[1].text.strip(),
                     'href': link.attrs['href']}
        download_links.append(link_info)
len(download_links)
# Out:
# 1097

# %%
roll_call_votes = [l for l in download_links if 'roll call' in l['title'].lower()]
roll_call_votes
# Out:
# [{'date': '2017-03-29',
#   'href': '/file/7189/download?token=bxMpAQh6',
#   'title': 'City Council - Attendance and Divided Roll Call Vote 3-29-2017'},
#  {'date': '2017-02-22',
#   'href': '/file/7165/download?token=kgouFPr6',
#   'title': 'City Council - Attendance and Divided Roll Call Vote 2-22-2017'},
#  {'date': '2017-01-25',
#   'href': '/file/7139/download?token=WbxqcBhj',
#   'title': 'City Council - Attendance and Divided Roll Call Vote 1-25-2017'},
#  {'date': '2016-12-14',
#   'href': '/file/7070/download?token=gQTk6kbQ',
#   'title': 'City Council - Attendance and Divided Roll Call Vote 12-14-2016'},
#  {'date': '2016-09-14',
#   'href': '/file/6986/download?token=LaaZKUeq',
#   'title': 'Attendance and Divided Roll Call Report 09/14/2016'},
#  {'date': '2016-06-23',
#   'href': '/file/6888/download?token=0xaUDVRg',
#   'title': 'Attendance and Divided Roll Call Report 06/22/2016'},
#  {'date': '2016-04-13',
#   'href': '/file/7150/download?token=5GN2as0G',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2016-03-16',
#   'href': '/file/6819/download?token=bASOiLX5',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2016-02-10',
#   'href': '/file/6782/download?token=nLjDGbFH',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-12-09',
#   'href': '/file/5661/download?token=b2NfNuDW',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-10-28',
#   'href': '/file/5568/download?token=40fb-74V',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-10-21',
#   'href': '/file/5550/download?token=TRDJsqFU',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-10-21',
#   'href': '/file/5550/download?token=TRDJsqFU',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-10-14',
#   'href': '/file/5549/download?token=mB4ObDIo',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-09-24',
#   'href': '/file/5242/download?token=sB6Wi8M8',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-07-29',
#   'href': '/file/5241/download?token=4f6YLQ2-',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-06-17',
#   'href': '/file/5240/download?token=Tibu20Dq',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-05-20',
#   'href': '/file/5239/download?token=JdXGuD33',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-05-06',
#   'href': '/file/5238/download?token=yRLzpwKf',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-04-15',
#   'href': '/file/5237/download?token=4KHVWfjD',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-03-18',
#   'href': '/file/5236/download?token=_aF0xhcL',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2015-01-21',
#   'href': '/file/5235/download?token=eSp2IVcY',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-12-10',
#   'href': '/file/5234/download?token=nPp9vOnz',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-12-02',
#   'href': '/file/5233/download?token=HAJOhjsD',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-11-19',
#   'href': '/file/5232/download?token=HG1k0wxX',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-11-12',
#   'href': '/file/5231/download?token=vhexFjGk',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-11-05',
#   'href': '/file/5230/download?token=6tHkw04_',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-09-10',
#   'href': '/file/5229/download?token=6G52mq5s',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-07-30',
#   'href': '/file/5228/download?token=Y0tjfCgE',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-06-25',
#   'href': '/file/5227/download?token=cIC3Uv5o',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-06-25',
#   'href': '/file/5227/download?token=cIC3Uv5o',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-05-28',
#   'href': '/file/5226/download?token=2UqA4fhV',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-04-30',
#   'href': '/file/5225/download?token=tN5D2lQ1',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-04-02',
#   'href': '/file/5224/download?token=ze7dNz1M',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-03-05',
#   'href': '/file/5223/download?token=xXlIK8q6',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-02-05',
#   'href': '/file/5222/download?token=ySbeT8bg',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2014-01-15',
#   'href': '/file/5221/download?token=gzN-AA8t',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-12-11',
#   'href': '/file/5220/download?token=6CdPu07e',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-11-13',
#   'href': '/file/5219/download?token=HMrPmwDx',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-10-16',
#   'href': '/file/5218/download?token=oXkWnm8l',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-09-11',
#   'href': '/file/5217/download?token=zLjEy1My',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-07-24',
#   'href': '/file/5216/download?token=uoDMDore',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-07-17',
#   'href': '/file/5215/download?token=a8rwWhaI',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-06-05',
#   'href': '/file/5214/download?token=iHwfYtBO',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-05-08',
#   'href': '/file/5213/download?token=kuBI2iTe',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-04-10',
#   'href': '/file/5212/download?token=6Mz2pFeb',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-03-13',
#   'href': '/file/5211/download?token=MhherQgZ',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-02-13',
#   'href': '/file/5210/download?token=NsZv6ICr',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2013-01-17',
#   'href': '/file/5209/download?token=KKXPCRr9',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-12-12',
#   'href': '/file/5208/download?token=xGKqAGlR',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-11-15',
#   'href': '/file/5207/download?token=yQBxZRJ7',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-11-08',
#   'href': '/file/5206/download?token=d01OoIHw',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-10-31',
#   'href': '/file/5243/download?token=bGhUgKHz',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-10-03',
#   'href': '/file/5205/download?token=J1ERCBuZ',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-09-12',
#   'href': '/file/5204/download?token=MewLVx0c',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-07-25',
#   'href': '/file/5109/download?token=sTm6MjL7',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-06-27',
#   'href': '/file/5110/download?token=boBFWcem',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-06-06',
#   'href': '/file/5111/download?token=SmAP1-dn',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-06-06',
#   'href': '/file/5111/download?token=SmAP1-dn',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-05-09',
#   'href': '/file/5112/download?token=O7BjWZ3u',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-04-24',
#   'href': '/file/5113/download?token=g3TBJwOE',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-04-18',
#   'href': '/file/5118/download?token=loCsFZsq',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-03-14',
#   'href': '/file/5117/download?token=4sNdmNRm',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-02-15',
#   'href': '/file/5116/download?token=ekTfOzqy',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-01-19',
#   'href': '/file/5115/download?token=MtVn1zuo',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2012-01-18',
#   'href': '/file/5114/download?token=4Ejn8KNU',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-12-14',
#   'href': '/file/5134/download?token=5ipw70Qf',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-11-16',
#   'href': '/file/5133/download?token=aG8YO09g',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-11-09',
#   'href': '/file/5132/download?token=vh-b3YPX',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-11-02',
#   'href': '/file/5131/download?token=_GIN4Ije',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-10-12',
#   'href': '/file/5130/download?token=bDFaWWyy',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-10-05',
#   'href': '/file/5129/download?token=JZGpz8lr',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-09-08',
#   'href': '/file/5128/download?token=1vmfO5Gm',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-07-28',
#   'href': '/file/5127/download?token=jA4_0vGh',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-07-06',
#   'href': '/file/5126/download?token=DgD8mezD',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-06-08',
#   'href': '/file/5125/download?token=EbrZVRHi',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-05-18',
#   'href': '/file/5124/download?token=RAICht_J',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-05-04',
#   'href': '/file/5123/download?token=KBMIz5hA',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-04-13',
#   'href': '/file/5122/download?token=ooj-3qRF',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-03-09',
#   'href': '/file/5121/download?token=xiu7rNyI',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-02-09',
#   'href': '/file/5120/download?token=JLtd0I3X',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-02-09',
#   'href': '/file/5120/download?token=JLtd0I3X',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2011-01-13',
#   'href': '/file/5119/download?token=edJr9JrS',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-12-08',
#   'href': '/file/5152/download?token=BqcGF604',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-11-17',
#   'href': '/file/5151/download?token=31vvAPCE',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-11-10',
#   'href': '/file/5150/download?token=FYuOAA_d',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-11-03',
#   'href': '/file/5149/download?token=MEWkiJk9',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-10-13',
#   'href': '/file/5148/download?token=FxAWT2RS',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-10-06',
#   'href': '/file/5147/download?token=Iz0J8tEv',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-09-08',
#   'href': '/file/5146/download?token=qFlk4E6M',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-07-28',
#   'href': '/file/5145/download?token=xoRehymg',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-07-28',
#   'href': '/file/5145/download?token=xoRehymg',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-07-02',
#   'href': '/file/5144/download?token=ODA22Td4',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-06-30',
#   'href': '/file/5143/download?token=EJvvAw6L',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-06-09',
#   'href': '/file/5142/download?token=g6tM9lrR',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-05-12',
#   'href': '/file/5141/download?token=LsXUTShO',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-04-14',
#   'href': '/file/5140/download?token=51dDataS',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-03-31',
#   'href': '/file/5139/download?token=lxceAu9z',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-03-26',
#   'href': '/file/5138/download?token=X7LXZpfw',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-03-10',
#   'href': '/file/5137/download?token=XGtW5Onf',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-02-10',
#   'href': '/file/5136/download?token=XPTPaim9',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2010-01-13',
#   'href': '/file/5135/download?token=mccSqYQl',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-12-16',
#   'href': '/file/5165/download?token=LFrETmo4',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-12-02',
#   'href': '/file/5164/download?token=d-MYuNAn',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-11-25',
#   'href': '/file/5163/download?token=Gjki1O0y',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-11-18',
#   'href': '/file/5162/download?token=AHFiI1co',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-10-07',
#   'href': '/file/5161/download?token=K9Ngxqgy',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-09-09',
#   'href': '/file/5160/download?token=h6ijQqcv',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-07-29',
#   'href': '/file/5159/download?token=YEZ3iQ5t',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-06-03',
#   'href': '/file/5158/download?token=6EoPfTfe',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-05-13',
#   'href': '/file/5157/download?token=e9PJuJxC',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-04-22',
#   'href': '/file/5156/download?token=YzCeR8AY',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-03-18',
#   'href': '/file/5155/download?token=0VtG8eUx',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-02-11',
#   'href': '/file/5154/download?token=KNo9fSQ9',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2009-01-13',
#   'href': '/file/5153/download?token=D8kXYV-Z',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-12-17',
#   'href': '/file/5179/download?token=xLFwHs47',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-12-04',
#   'href': '/file/5178/download?token=3_mpoKIx',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-11-19',
#   'href': '/file/5177/download?token=u_pkZ2Ew',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-11-12',
#   'href': '/file/5176/download?token=YkBWEgeh',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-11-05',
#   'href': '/file/5175/download?token=9Wh0myjz',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-10-08',
#   'href': '/file/5174/download?token=cRpwt-ZX',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-09-10',
#   'href': '/file/5173/download?token=k7f3a18B',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-07-30',
#   'href': '/file/5172/download?token=q_1X_87q',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-06-11',
#   'href': '/file/5171/download?token=PuUSycv-',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-05-14',
#   'href': '/file/5170/download?token=QhUKTqnC',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-04-09',
#   'href': '/file/5169/download?token=MJ9XAv2P',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-03-12',
#   'href': '/file/5168/download?token=MBx-hI6G',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-02-06',
#   'href': '/file/5167/download?token=USAsHQ9J',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2008-01-09',
#   'href': '/file/5166/download?token=1ihm72L7',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-12-12',
#   'href': '/file/5193/download?token=5d4Vu9gv',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-11-13',
#   'href': '/file/5192/download?token=VPMlbZgK',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-11-07',
#   'href': '/file/5191/download?token=JIB0-lX1',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-10-31',
#   'href': '/file/5190/download?token=GOMqaaot',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-09-27',
#   'href': '/file/5189/download?token=h9TSJK9Y',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-09-05',
#   'href': '/file/5188/download?token=AoTnNUA9',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-07-19',
#   'href': '/file/5187/download?token=nINI98a4',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-06-13',
#   'href': '/file/5186/download?token=yAcYKHxL',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-05-23',
#   'href': '/file/5185/download?token=loihhLBP',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-05-09',
#   'href': '/file/5184/download?token=vU9snBNz',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-04-11',
#   'href': '/file/5183/download?token=_YLTf-e5',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-03-14',
#   'href': '/file/5182/download?token=BXfZtMic',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-02-07',
#   'href': '/file/5181/download?token=23AsvpfC',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2007-01-11',
#   'href': '/file/5180/download?token=xqz6UJPn',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-12-13',
#   'href': '/file/5203/download?token=5WEhzz_e',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-11-19',
#   'href': '/file/5202/download?token=mD80bnaQ',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-11-15',
#   'href': '/file/5201/download?token=ZqFueUdq',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-11-08',
#   'href': '/file/5200/download?token=WklBSzLr',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-11-01',
#   'href': '/file/5199/download?token=6XmJ9zZc',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-10-04',
#   'href': '/file/5198/download?token=as1Q4BUQ',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-09-13',
#   'href': '/file/5197/download?token=WbP0RB-M',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-07-26',
#   'href': '/file/5196/download?token=Sy44HdJm',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-06-28',
#   'href': '/file/5195/download?token=ZfWigW-T',
#   'title': 'Attendance and Divided Roll Call Report'},
#  {'date': '2006-05-24',
#   'href': '/file/5194/download?token=taMlD5HE',
#   'title': 'Attendance and Divided Roll Call Report'}]

# %%
print(len(roll_call_votes))
# Out:
# 153

# %%
def download_link(doc_link):
    local_name = doc_link['date'].replace('-', '') + '_roll_call_report.pdf'
    path = os.path.join(os.path.expanduser('~'), 'projects', 'd4d', 'chicago-lobbyists', 'roll_calls', local_name)
    url = base + doc_link['href'].lstrip('/')
    try:
        print('Downloading "{}" from {}'.format(doc_link['title'], url))
        return urllib.request.urlretrieve(url, filename=path)
    except:
        print("Failed!")

# %%
download_resp = []
for doc_link in roll_call_votes:
    local_name = doc_link['date'].replace('-', '') + '_roll_call_report.pdf'
    path = os.path.join(WORKING_DIR, 'roll_calls', local_name)
    url = base + doc_link['href'].lstrip('/')
    try:
        print("Downloading {}".format(url))
        download_resp.append(urllib.request.urlretrieve(url, filename=path))
    except:
        print("Failed")

# %%
download_resp

# %% [markdown]
# # Parse Voting Records
#
# There's two formats of voting records. The older format has a single table indexed by ward # and Alderman name, with a matrix of votes. The column names are the record numbers of the measures being considered on that day. Titles of each measure are in the block of text above the voting records. I've called this format the "vote table". Parsing is controlled by the "parse_file_with_table" function.
#
# The newer format has one vote per page. Each page has the record name, title, and a block of warn # and Alderman name with votes in two columns. I've called this a "vote block" format. Parsing is controlled by the "parse_file_with_blocks" function. First I locate each block (each measure considered), then parse that block. Some tables translated cleanly from pdf -- these use the "parse_vote_block_clean" function. Some got a bit scrambled -- those use the "parse_vote_block_dirty" function.
#
# For both formats, I've special-cased a few documents that didn't parse cleanly for one reason or another.

# %%
# This cell contains the code for converting vote blocks 
# of the newer format into DataFrames of voting records.

columns = ['Ward', 'Alderman', 'Vote']
VOTE_TOKENS = ['Y', 'N', 'A', 'NV', 'V', 'E', 'R', 'Recused', '-']


def standardize_name(name: str) -> str:
    """Standardize names of Aldermen"""
    if name.lower() in ['vacant', 'vacancy']:
        name = 'vacant'
    elif name == 'Ramirez Garza Rosa':
        # This is a common scrambling of "Ramirez Rosa" and "Sadlowski Garza"
        name = 'Ramirez Rosa'
    elif name == 'Sadlowski':
        name = 'Sadlowski Garza'
    elif name == 'Timothy M.':
        name = 'Timothy M. Cullerton'
    elif name == 'George A.':
        name = 'George A. Cárdenas'
    return name


def is_number(token: str):
    try:
        int(token)
        return True
    except ValueError:
        return False

    
def next_index_with_condition(line: List[str], condition):
    for i_token, token in enumerate(line):
        if condition(token):
            return i_token


def vote_from_token_end(token: str) -> Tuple[str, str]:
    if token == 'VACANCY':
        return None, token
    elif token[-2:] in VOTE_TOKENS:
        return token[-2:], token[:-2]
    elif token[-1] in VOTE_TOKENS:
        return token[-1], token[:-1]
    else:
        return None, token
    

# Special casing for corner cases and single document errors.
# Use these to clean lines.
SPECIAL_LINE_CLEANING = [('YO’Connor', 'Y O’Connor'),
                        ('AO’Connor', 'A O’Connor'),
                        ('V41', 'V 41'),
                        ('Brookins45 Cappleman YY', 'Brookins 45 Cappleman Y Y'),
                        ('PaY war', 'Pawar Y'),
                        ('OstermaY n', 'Osterman Y'),
                        ('Jackson32', 'Jackson 32'),
                        ('Thompson36', 'Thompson 36'),
                        ('denas37', 'denas 37'),
                        ('Napolitano NY', 'Napolitano N Y'),
                        ('Napolitano YY', 'Napolitano Y Y'),
                        ('34 Y', 'Y 34'),
                        ('Brookins45 Capple Y man Y',
                         'Brookins 45 Cappleman Y Y'),
                        ('N Rosa', 'Rosa N'),
                        ('Y Rosa', 'Rosa Y'),
                        ('Sadlowski 35 RaGarza mirez Rosa',
                         'Sadlowski Garza 35 Ramirez Rosa')]


def correct_record_miscodings(record: Dict[str, str]) -> Dict[str, str]:
    """Correct known data entry errors or inconsistencies
    
    Input should be a dictionary with keys "Ward", "Alderman", "Vote"
    """
    record = record.copy()  # Don't alter input
    if record['Alderman'] == 'Cappleman' and record['Ward'] == '45':
        record['Ward'] = '46'
    if record['Vote'] == 'Recused':
        record['Vote'] = 'R'
    return record


def parse_vote_block_dirty(lines: List[str]) -> pd.DataFrame:
    # This works on a vote block with messed up formatting.
    # Assume lines are organized as
    # WARD1 NAME1 WARD2 NAME2 VOTE1 VOTE2
    # The "VOTE1" may or may not have whitespace between it and NAME2
    # Possibly VOTE1 is between NAME1 and WARD2 for some lines.
    
    votes = []
    for i, line in enumerate(lines):
        if not line:
            break
        #print(line)
        line = ' '.join(line.split())  # Convert all whitespace to one space
        for special in SPECIAL_LINE_CLEANING:
            line = line.replace(*special)
        #print(line)
        tokens = line.split()
        #tokens = list(chain.from_iterable([split_vote_token(t) for t in line.split()]))
        clean_tokens = [], []
        stage = 0
        clean_tokens[0].append(tokens.pop(0))
        
        i_next_ward = next_index_with_condition(tokens, is_number)
        name_0 = ' '.join(tokens[:i_next_ward]).strip()
        vote_0, name_0 = vote_from_token_end(name_0)
        clean_tokens[0].append(name_0.strip())
        clean_tokens[1].append(tokens[i_next_ward])
        
        tokens = tokens[i_next_ward + 1:]  # Remove consumed tokens
        vote_1 = tokens.pop(len(tokens) - 1)  # Last token is the second vote
        
        # Remaining tokens are a combination of first vote and second name
        if not vote_0:
            vote_0, tokens[-1] = vote_from_token_end(tokens[-1])
        if not vote_0:
            vote_0 = tokens.pop(1)
        clean_tokens[0].append(vote_0)
        
        name_1 = ' '.join(tokens).strip()
        if not name_1 and vote_1 not in VOTE_TOKENS:
            # Probably the name and last vote merged together.
            vote_1, name_1 = vote_from_token_end(vote_1)
        clean_tokens[1].append(name_1)
        clean_tokens[1].append(vote_1)
        
        for cleaned in clean_tokens:
            record = dict(zip(columns, cleaned))
            votes.append(correct_record_miscodings(record))
    df = pd.DataFrame.from_records(votes)
    df['Ward'] = df['Ward'].astype(int)
    df['Alderman'] = df['Alderman'].apply(standardize_name)
    
    assert len(df) == 50, "There should be 50 wards"
    assert (np.sort(df['Ward'].values) == np.arange(1, 51)).all(),\
        "Wards should be 1-50"
    
    return df.sort_values(by='Ward').reset_index(drop=True)


def parse_vote_block_clean(lines: List[str]) -> pd.DataFrame:
    # This works on a well-formatted vote block
    votes = []
    # Go over enough lines to be sure you have it all. Break when done.
    for i, line in enumerate(lines):
        if not line:
            break
        tokens = line.split()
        clean_tokens = []
        stage = 0
        name_tokens = []
        for t in tokens:
            if stage == 0:
                clean_tokens.append(t)
                stage += 1
            elif stage == 1:
                if t in VOTE_TOKENS:
                    clean_tokens.append(' '.join(name_tokens))
                    clean_tokens.append(t)
                    record = dict(zip(columns, clean_tokens))
                    votes.append(correct_record_miscodings(record))
                    clean_tokens, name_tokens = [], []
                    stage = 0
                else:
                    name_tokens.append(t)
    df = pd.DataFrame.from_records(votes)
    df['Ward'] = df['Ward'].astype(int)
    df['Alderman'] = df['Alderman'].apply(standardize_name)
    
    assert len(df) == 50, "There should be 50 wards"
    assert (np.sort(df['Ward'].values) == np.arange(1, 51)).all(),\
        "Wards should be 1-50"
    
    return df.sort_values(by='Ward').reset_index(drop=True)

# %%
# This cell finds the portions of data in the newer format -- 
# record indicator, title, and voting data -- and cleans and 
# wraps everything into one dictionary per vote.

def startswith_index(page, i_start, substr):
    for i, l in enumerate(page[i_start:]):
        if l.strip().lower().startswith(substr.lower()):
            return i + i_start

def select_chunks(page):
    chunks, starts, stops = {}, {}, {}
    end_index = None
    
    i_roll_call_page = startswith_index(page, 0, 'Roll Call Vote')
    if not i_roll_call_page:
        return chunks, end_index
    
    starts['record'] = startswith_index(page, i_roll_call_page, 'Record')
    stops['record'] = starts['record'] + 1
    starts['title'] = startswith_index(page, starts['record'], 'Title')
    stops['title'] = startswith_index(page, starts['title'], 'Vote')
    starts['votes'] = startswith_index(page, stops['title'], 'Ward') + 1
    if page[starts['votes']].strip().startswith('Ward'):
        # Sometimes the table header splits onto two lines
        # E.g. roll_calls/20131211_roll_call_report.txt
        starts['votes'] += 1
    for i in range(starts['votes'], len(page)):
        if not page[i].strip() or page[i].strip()[0] not in string.digits:
            stops['votes'] = i
            break
    else:
        raise RuntimeError("Couldn't find the end of the vote block.")
    
    for name in starts:
        chunks[name] = page[starts[name]: stops[name]]
        
    return chunks, stops['votes'] + 1

   
def clean_record(line: str) -> str:
    if len(line) != 1:
        raise ValueError('Expected one line!')
    return line[0].split()[-1]
    #return line[0][len('Record No.:'):].strip()

def clean_title(lines: List[str]) -> str:
    line = ' '.join(lines)
    tokens = line.split()
    return ' '.join(tokens[1:])
    #return line[len('Title/Description:'):].strip()

def clean_votes(lines: List[str]) -> pd.DataFrame:
    try:
        return parse_vote_block_clean(lines)
    except (ValueError, KeyError):
        return parse_vote_block_dirty(lines)

CLEAN = {'record': clean_record, 'title': clean_title, 'votes': clean_votes}


def read_page(file_name: str) -> List[str]:
    with open(file_name) as _fin:
        page = [l.strip() for l in _fin.readlines()]
    return page


def parse_file_with_blocks(file_name: str, date_str: str) -> List[Dict]:
    records = []
    page = read_page(file_name)
    index = 0
    while True:
        this_rec, next_index = select_chunks(page[index:])
        if this_rec:
            records.append({k: CLEAN[k](v) for k, v in this_rec.items()})
            records[-1]['date'] = date_str
            index += next_index
        else:
            break
    return records

# %%
# This cell parses voting records in the older style.

def select_vote_table(lines: List[str], votes_only: bool=False) -> List[str]:
    # Search for a unified table of votes
    i_start, i_stop = None, None
    for i_line, line in enumerate(lines):
        if ('issue:' in line.strip().lower() and 
                (lines[i_line + 1].strip().startswith('1st') or
                 lines[i_line + 2].strip().startswith('1st'))):
            i_start = i_line
        elif votes_only and line.strip().startswith('1st'):
            # We already have the header, so we only need the block of votes
            i_start = i_line
        elif i_start and line.strip().startswith('50th'):
            i_stop = i_line + 1
            break
    else:
        return []
    return lines[i_start: i_stop]

def parse_table_line(line: str, n_issues: int) -> Tuple[str, str, str]:
    tokens = line.split()
    if len(tokens) < 3:
        return None
    ward = tokens.pop(0)[:-2]  # Remove "st", "nd", "th", etc.
    tokens.pop(0)  # Should be "Ward:"
    
    votes = []
    while tokens[-1] in VOTE_TOKENS:
        votes.append(tokens.pop(len(tokens) - 1))
    additional_vote, tokens[-1] = vote_from_token_end(tokens[-1])
    while additional_vote:
        votes.append(additional_vote)
        additional_vote, tokens[-1] = vote_from_token_end(tokens[-1])
    votes = votes[::-1]  # Invert list -- we processed from the end inward
        
    name = ' '.join(tokens)
    if name.lower() == 'vacant' and not votes:
        votes = n_issues * ['V']
    return [ward, name] + votes


def get_title(page: List[str], issue: str) -> str:
    if issue.startswith('ADJOURN'):
        return "Motion to adjourn"
    if issue.lower().startswith('case of'):
        return issue
    if issue == 'O2009-6230':
        # The title detail was miscoded in the pdfs as "O2010-6230"
        return ("Amendment of Chapter 2-32 of Municipal "
                "Code by addition of new Section 6267 establishing "
                "property tax relief program for qualified homeowners.")
    issue = issue.replace(';', ',')
    issue = issue.replace('(v', ' (v')
    for i_line, line in enumerate(page):
        if line.strip().startswith(issue):
            break
            
    possible_title_lines = [page[i_line]]
    for line in page[i_line+1: i_line+10]:
        line = line.strip()
        if line.lower().lstrip('(').strip().startswith('click here'):
            continue
        elif (not line or 
                line.lower().startswith("key: ") or 
                re.search(r'^[A-Z][a-zA-Z]?\d{4}-', line)):
            break
        possible_title_lines.append(line)
    blob = ' '.join(possible_title_lines)
    i_end = blob.lower().find('click here')
    title = blob[: i_end] if i_end > 0 else blob
    title = title[len(issue) + 1:].strip().lstrip('-').strip()
    title = title.rstrip('(').strip()
    return title


def parse_issues(lines: List[str]) -> List[str]:
    # Convert lines of text with issue record names into a list of names
    # Need to handle line breaks.
    # See e.g. roll_calls/20071113_roll_call_report.txt

    # Differently-broken:
    # roll_calls/20061115_roll_call_report.txt
    
    # Remove spaces from "Motion to Adjourn" to aid in processing
    lines[0] = lines[0].replace('Motion to Adjourn', 'ADJOURN')
    
    if len(lines) == 1:
        return ''.join([l.strip().replace('--', '-') for l in lines]).split()[1:]
    if len(lines) == 2:
        if ';' in lines[0]:
            lines[0].replace('; ', ';')
        elif Counter(lines[0])['-'] > len(lines[0].split()) - 1:
            lines[0] = lines[0].replace('-', '- ').replace(' - ', ' ')
        lines[1] = lines[1].replace(' (', '(')
        tokens1 = lines[0].split()[1:]  # Remove "Issue:"
        tokens2 = lines[1].split()
        if len(tokens2) == 1:
            return ''.join([l.strip().replace('--', '-') for l in lines]).split()[1:]
        elif len(tokens2) == len(tokens1):
            return [''.join(pair).replace('--', '-') for pair in zip(tokens1, tokens2)]
    raise RuntimeError('Unable to parse issues: \n{}'.format(lines))

        
def parse_file_with_table(file_name: str, date_str: str, issues: List[str]=None) -> List[Dict]:
    records = []
    page = read_page(file_name)
    
    vote_table = select_vote_table(page, votes_only=(issues is not None))
    if not vote_table:
        return
    
    if not issues:
        i_start = [i for i, l in enumerate(vote_table) if l.startswith('1st')][0]
        issues = parse_issues(vote_table[: i_start])
    else:
        i_start = 0
    parsed_lines = [parse_table_line(l, len(issues)) for l in vote_table[i_start:] if len(l.split()) >= 3]
    df = pd.DataFrame.from_records(parsed_lines, columns=['Ward', 'Alderman'] + issues)
    df['Ward'] = df['Ward'].astype(int)
    df['Alderman'] = df['Alderman'].apply(standardize_name)
    
    assert len(df) == 50, "There should be 50 wards"
    assert (np.sort(df['Ward'].values) == np.arange(1, 51)).all(),\
        "Wards should be 1-50"
    
    for issue in issues:
        record = {'record': issue,
                  'title': get_title(page, issue),
                  'date': date_str,
                  'votes': df[['Alderman', issue, 'Ward']].rename(columns={issue: 'Vote'})}
        records.append(record)
    return records

# %%
# Hand-inspected records, verified to have no votes that day (attendance only)
known_empty = ['/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110309_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110413_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110504_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110518_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110706_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111005_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111012_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111102_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111109_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111214_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120314_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120509_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121003_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130117_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130213_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130313_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130717_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20131016_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140402_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141210_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150121_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150415_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150506_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150520_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151014_roll_call_report.txt',
 '/Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151021_roll_call_report.txt']

# There's odd things in these files which keep them from being parsed easily.
# Hand-code the issue headers. (These are for old-style formatted documents only.)
issues_for_date = {'2009-10-07': ['SO2009-5597','SO2009-5542', 
                                  'PO2009-4114: Motion to lay on table', 
                                  'PO2009-4114: Motion to Re-refer'],
                   '2006-11-19': ['O2008-6775', 'O2008-6776', 'O2008-6782', 'O2008-6778', 'SO2008-6777'],
                   '2010-09-08': ['Case of Gary Kamen v. City of Chicago.'],
                   '2011-02-09': ['SO2010-7086; O2010-6824'],
                   '2012-04-24': ['Table Fioretti Amendment', 'Table Waguespack Substitute', 'SO2012-1366']}

# %%
# Use GhostScript to convert all of the pdfs into text files,
# then parse the text files.
cmd = 'gs -sDEVICE=txtwrite -o {output} {input}'

vote_records = []
empty = []
unknown = []
success = []
fail = []
val = None
pdfs = glob(os.path.abspath('roll_calls/*.pdf'))
for i_name, fname in enumerate(pdfs):
    out_fname = os.path.splitext(fname)[0] + '.txt'
    if not os.path.exists(out_fname):
        # Only reprocess the pdfs if the outputs don't exist already.
        retval = subprocess.run(cmd.format(output=out_fname, input=fname),
                                shell=True, check=False,
                                stderr=subprocess.PIPE, stdout=subprocess.PIPE)
    #print(retval.stdout, retval.stderr)
    print("Parsing {} from {}".format(fname, out_fname))
    try:
        with open(out_fname) as _fin:
            full_page = _fin.read()
            
        # Many documents have only attendance and no votes. Skip those.
        if (out_fname in known_empty or
                'There were no divided roll call votes' in full_page or
                'There was no divided roll call' in full_page):
            empty.append(out_fname)
            continue
            
        # First try to parse the document as if it were in the new-style format.
        yyyymmdd = os.path.basename(out_fname).split('_')[0]
        date_str = "{}-{}-{}".format(yyyymmdd[:4], yyyymmdd[4:6], yyyymmdd[6:])
        parsed = parse_file_with_blocks(out_fname, date_str=date_str)
        if not parsed:
            # If that didn't work, try again with the older format.
            parsed = parse_file_with_table(out_fname, date_str=date_str, 
                                           issues=issues_for_date.get(date_str))
            
        # Record success or failure.
        if not parsed:
            unknown.append(out_fname)
        else:
            success.append(out_fname)
            vote_records.extend(parsed)
    except Exception as exc:
        fail.append((out_fname, exc))
        print(exc)
# Out:
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060524_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060524_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060628_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060628_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060726_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060726_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060913_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20060913_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061004_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061004_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061101_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061101_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061108_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061108_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061115_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061115_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061119_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061119_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061213_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20061213_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070111_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070111_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070207_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070207_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070314_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070314_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070411_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070411_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070509_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070509_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070523_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070523_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070613_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070613_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070719_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070719_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070905_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070905_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070927_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20070927_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071031_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071031_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071107_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071107_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071113_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071113_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071212_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20071212_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080109_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080109_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080206_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080206_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080312_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080312_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080409_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080409_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080514_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080514_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080611_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080611_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080730_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080730_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080910_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20080910_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081008_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081008_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081105_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081105_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081112_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081112_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081119_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081119_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081204_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081204_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081217_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20081217_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090113_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090113_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090211_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090211_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090318_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090318_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090422_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090422_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090513_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090513_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090603_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090603_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090729_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090729_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090909_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20090909_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091007_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091007_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091118_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091118_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091125_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091125_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091202_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091202_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091216_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20091216_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100113_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100113_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100210_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100210_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100310_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100310_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100326_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100326_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100331_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100331_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100414_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100414_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100512_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100512_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100609_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100609_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100630_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100630_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100702_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100702_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100728_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100728_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100908_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20100908_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101006_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101006_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101013_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101013_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101103_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101103_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101110_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101110_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101117_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101117_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101208_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20101208_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110113_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110113_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110209_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110209_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110309_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110309_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110413_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110413_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110504_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110504_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110518_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110518_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110608_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110608_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110706_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110706_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110728_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110728_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110908_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20110908_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111005_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111005_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111012_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111012_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111102_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111102_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111109_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111109_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111116_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111116_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111214_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20111214_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120118_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120118_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120119_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120119_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120215_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120215_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120314_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120314_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120418_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120418_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120424_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120424_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120509_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120509_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120606_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120606_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120627_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120627_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120725_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120725_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120912_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20120912_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121003_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121003_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121031_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121031_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121108_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121108_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121115_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121115_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121212_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20121212_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130117_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130117_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130213_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130213_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130313_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130313_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130410_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130410_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130508_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130508_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130605_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130605_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130717_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130717_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130724_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130724_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130911_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20130911_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20131016_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20131016_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20131113_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20131113_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20131211_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20131211_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140115_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140115_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140205_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140205_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140305_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140305_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140402_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140402_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140430_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140430_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140528_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140528_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140625_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140625_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140730_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140730_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140910_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20140910_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141105_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141105_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141112_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141112_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141119_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141119_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141202_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141202_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141210_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20141210_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150121_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150121_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150318_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150318_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150415_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150415_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150506_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150506_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150520_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150520_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150617_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150617_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150729_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150729_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150924_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20150924_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151014_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151014_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151021_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151021_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151028_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151028_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151209_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20151209_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160210_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160210_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160316_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160316_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160413_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160413_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160623_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160623_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160914_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20160914_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20161214_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20161214_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20170125_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20170125_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20170222_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20170222_roll_call_report.txt
# Parsing /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20170329_roll_call_report.pdf from /Users/shoover/projects/d4d/chicago-lobbyists/roll_calls/20170329_roll_call_report.txt

# %%
print('{} vote records successfully parsed from {} files.'.format(len(vote_records), len(success)))
print(len(empty), ' files have no votes.')
print(len(fail), ' files had an error in parsing.')
print(len(unknown), ' files I don\'t know how to parse.')
# Out:
# 217 vote records successfully parsed from 90 files.
# 58  files have no votes.
# 0  files had an error in parsing.
# 0  files I don't know how to parse.

# %%
def read_date(date):
    return read_page(os.path.join(WORKING_DIR, 'roll_calls', '{}_roll_call_report.txt'.format(date.replace('-', ''))))

# %%
fail
# Out:
# []

# %%
vote_records[130]
# Out:
# {'date': '2014-02-05',
#  'record': 'O2014-500',
#  'title': 'City of Chicago General Obligation and Refunding Bonds, Series 2014 and amend Chapter 2-32 of Municipal Code of Chicago concerning debt management policies',
#  'votes':        Alderman Vote  Ward
#  0        Moreno    Y     1
#  1      Fioretti    N     2
#  2        Dowell    Y     3
#  3         Burns    Y     4
#  4      Hairston    Y     5
#  5        Sawyer    Y     6
#  6        Holmes    Y     7
#  7        Harris    Y     8
#  8         Beale    Y     9
#  9          Pope    Y    10
#  10       Balcer    Y    11
#  11     Cárdenas    Y    12
#  12        Quinn    Y    13
#  13        Burke    R    14
#  14      Foulkes    Y    15
#  15     Thompson    Y    16
#  16       Thomas    Y    17
#  17         Lane    Y    18
#  18       O’Shea    Y    19
#  19      Cochran    Y    20
#  20     Brookins    Y    21
#  21        Muñoz    Y    22
#  22     Zalewski    Y    23
#  23     Chandler    Y    24
#  24        Solis    Y    25
#  25    Maldonado    Y    26
#  26      Burnett    Y    27
#  27        Ervin    Y    28
#  28       Graham    Y    29
#  29     Reboyras    Y    30
#  30       Suarez    Y    31
#  31   Waguespack    N    32
#  32         Mell    Y    33
#  33       Austin    Y    34
#  34        Colón    Y    35
#  35      Sposato    Y    36
#  36        Mitts    Y    37
#  37    Cullerton    Y    38
#  38      Laurino    Y    39
#  39  P. O’Connor    A    40
#  40  M. O’Connor    Y    41
#  41       Reilly    N    42
#  42        Smith    Y    43
#  43       Tunney    Y    44
#  44        Arena    N    45
#  45    Cappleman    Y    46
#  46        Pawar    Y    47
#  47     Osterman    Y    48
#  48        Moore    Y    49
#  49  Silverstein    Y    50}

# %%
# Inspect pages
read_page(empty[4])
# Out:
# ['Attendance and Divided Roll Call                               Close',
#  'Vote',
#  'Attendance for the February 7th, 2007 Meeting of the Chicago City',
#  'Council',
#  'Present - The Honorable Richard M. Daley, Mayor, and Aldermen Flores, Haithcock,',
#  'Tillman, Preckwinkle, Hairston, Lyle, Beavers, Stroger, Beale, Pope, Balcer, Cardenas,',
#  'Olivo, Burke, T. Thomas, Coleman, L.Thomas, Murphy, Rugai, Troutman, Brookins,',
#  'Munoz, Zalewski, Chandler, Solis, Ocasio, Burnett, E. Smith, Carothers, Reboyras,',
#  "Suarez, Matlak, Mell, Austin, Colon, Banks, Mitts, Allen, Laurino, O'Connor, Doherty,",
#  'Natarus, Daley, Tunney, Levar, Shiller, Schulter, M. Smith, Moore, Stone.',
#  'Absent - None.',
#  'Divided Roll Call Voting February 7th, 2007 Meeting of the Chicago City',
#  'Council',
#  'There were no divided roll call votes in the February 7th, 2007 meeting of the Chicago City',
#  'Council.']

# %%
# Error checking / debugging

fname = fail[0][0]
print(fname)
page = read_page(fname)
votes = select_chunks(page)
print(votes[1])
parse_vote_block_dirty(votes[0]['votes'])
#parse_file_with_table(fname, 'yyyy')

# %% [markdown]
# # Output Data
#
# Write the data to disk!

# %%
df_records_list = []
titles = []
for record in vote_records:
    _df = record['votes'].copy()
    _df['Date'] = record['date']
    _df['Record'] = record['record']
    df_records_list.append(_df)
    titles.append([record['date'], record['record'], record['title']])
    
df_records = pd.concat(df_records_list)
df_titles = pd.DataFrame(titles, columns=['Date', 'Record', 'Title'])

# %%
df_records.to_csv(os.path.join(WORKING_DIR, 'alderman_votes.csv'), index=False)
df_titles.to_csv(os.path.join(WORKING_DIR, 'legislation_titles.csv'), index=False)

# %% [markdown]
# # Quality Checks

# %%
from collections import Counter
Counter(df_records.Ward)
# Out:
# Counter({1: 217,
#          2: 217,
#          3: 217,
#          4: 217,
#          5: 217,
#          6: 217,
#          7: 217,
#          8: 217,
#          9: 217,
#          10: 217,
#          11: 217,
#          12: 217,
#          13: 217,
#          14: 217,
#          15: 217,
#          16: 217,
#          17: 217,
#          18: 217,
#          19: 217,
#          20: 217,
#          21: 217,
#          22: 217,
#          23: 217,
#          24: 217,
#          25: 217,
#          26: 217,
#          27: 217,
#          28: 217,
#          29: 217,
#          30: 217,
#          31: 217,
#          32: 217,
#          33: 217,
#          34: 217,
#          35: 217,
#          36: 217,
#          37: 217,
#          38: 217,
#          39: 217,
#          40: 217,
#          41: 217,
#          42: 217,
#          43: 217,
#          44: 217,
#          45: 217,
#          46: 217,
#          47: 217,
#          48: 217,
#          49: 217,
#          50: 217})

# %%
df_records.Alderman.unique()
# Out:
# array(['Manuel Flores', 'Madeline L. Haithcock', 'Dorothy J. Tillman',
#        'Toni Preckwinkle', 'Leslie Hairston', 'Freddrenna Lyle',
#        'William M. Beavers', 'Todd Stroger', 'Anthony Beale',
#        'John A. Pope', 'James A. Balcer', 'George A. Cardenas',
#        'Frank J. Olivo', 'Edward M. Burke', 'Theodore Thomas',
#        'Shirley A. Coleman', 'LaTasha R. Thomas', 'Thomas W. Murphy',
#        'Virginia A. Rugai', 'Arenda Troutman', 'Howard Brookins Jr.',
#        'Ricardo Munoz', 'Michael R. Zalewski', 'Michael D. Chandler',
#        'Daniel S. Solis', 'Billy Ocasio', 'Walter Burnett, Jr.',
#        'Ed H. Smith', 'Isaac S. Carothers', 'Ariel E. Reboyras',
#        'Ray Suarez', 'Ted Matlak', 'Richard F. Mell', 'Carrie M. Austin',
#        'Rey Colon', 'William J.P. Banks', 'Emma Mitts', 'Thomas R. Allen',
#        'Margaret Laurino', "Patrick J. O'Connor", 'Brian G. Doherty',
#        'Burton F. Natarus', 'Vi Daley', 'Thomas Tunney',
#        'Patrick J. Levar', 'Helen Shiller', 'Eugene C. Schulter',
#        'Mary Ann Smith', 'Joe Moore', 'Bernard L. Stone',
#        "Patrick J. O'Conner", 'Darcel Beavers', 'Michelle Harris',
#        'Lona Lane', 'Robert Fioretti', 'Pat Dowell', 'Sandy Jackson',
#        'Toni Foulkes', 'Joann Thompson', 'Latasha R. Thomas',
#        'Willie Cochran', 'Sharon Denise Dixon', 'Scott Waguespack',
#        'Brendan Reilly', 'Patrick J. O’Connor', 'George A. Cárdenas',
#        'Ricardo Muñoz', 'Rey Colón', 'vacant', 'Roberto Maldonado',
#        'John A. Rice', 'Proco Joe Moreno', 'Deborah Graham',
#        'Sharon Denise', 'Shirley Newsome', 'Jason Ervin',
#        'Timothy Cullerton', 'William Burns', 'Roderick Sawyer',
#        'Marty Quinn', "Matthew O'Shea", 'Michael Chandler',
#        'Jason C. Ervin', 'Deborah L. Graham', 'Regner Ray Suarez',
#        'Nicholas Sposato', 'Timothy M. Cullerton', "Mary O'Connor",
#        'Michele Smith', 'John Arena', 'James Cappleman', 'Ameya Pawar',
#        'Harry Osterman', 'Debra Silverstein', 'Matthew O’Shea',
#        'Howard Brookins, Jr.', 'Mary O’Connor', 'William D. Burns',
#        'Leslie A. Hairston', 'Roderick T. Sawyer', 'Sandi Jackson',
#        'Michelle A. Harris', 'Matthew J. O’Shea', 'Daniel Solis',
#        'Joseph A. Moore', 'Debra L. Silverstein', 'Moreno', 'Fioretti',
#        'Dowell', 'Burns', 'Hairston', 'Sawyer', 'Jackson', 'Harris',
#        'Beale', 'Pope', 'Balcer', 'Cárdenas', 'Quinn', 'Burke', 'Foulkes',
#        'Thompson', 'Thomas', 'Lane', 'O’Shea', 'Cochran', 'Brookins',
#        'Muñoz', 'Zalewski', 'Chandler', 'Solis', 'Maldonado', 'Burnett',
#        'Ervin', 'Graham', 'Reboyras', 'Suarez', 'Waguespack', 'Mell',
#        'Austin', 'Colón', 'Sposato', 'Mitts', 'Cullerton', 'Laurino',
#        'P. O’Connor', 'M. O’Connor', 'Reilly', 'Smith', 'Tunney', 'Arena',
#        'Cappleman', 'Pawar', 'Osterman', 'Moore', 'Silverstein', 'Holmes',
#        'Hopkins', 'Mitchell', 'Sadlowski Garza', 'Lopez', 'D. Moore',
#        'Curtis', 'Scott', 'Taliaferro', 'Santiago', 'Ramirez Rosa',
#        'Villegas', 'O’Connor', 'Napolitano', 'J. Moore', 'King'], dtype=object)

# %%
df_records.Vote.unique()
# Out:
# array(['N', 'Y', 'NV', 'A', 'E', 'V', '-', 'R'], dtype=object)

# %%
print(df_records.Record.nunique())
df_records.Record.unique()
# Out:
# 211
# array(['SO2006-3086', 'SO2006-2971', 'FL2006-14', 'SO2006-3936',
#        'F2006-230', 'A2006-103', 'SO2006-3966', 'O2006-4519', 'O2006-4522',
#        'OR2006-1552', 'O2006-4891', 'O2006-4893', 'O2006-4894',
#        'SO2006-5062', 'O2008-6775', 'O2008-6776', 'O2008-6782',
#        'O2008-6778', 'SO2008-6777', 'O2006-5187', 'S02007-464',
#        'O2007-1402', 'R2007-1058', 'O2007-3106', 'OR2007-1009',
#        'SO2007-3954', 'SO2007-5794', 'O2007-5503', 'SO2007-5799',
#        'SO2007-5800', 'SO2007-5802', 'SO2007-5801', 'A2008-2',
#        'SO2008-537', 'O2008-538', 'O2008-2041', 'S02008-2623',
#        'SO2008-4315', 'SO2008-4302', 'O2008-6777', 'O2008-6774',
#        'O2008-7304', 'Or2009-1', 'SO2009-1115', 'SO2009-2414',
#        'O2009-2415', 'SO2009-3410', 'SO2009-5597', 'SO2009-5542',
#        'PO2009-4114: Motion to lay on table',
#        'PO2009-4114: Motion to Re-refer', 'R2009-1210', 'O2009-6224',
#        'O2009-6223', 'O2009-6230', 'SO2010-163', 'ADJOURN#1', 'ADJOURN#2',
#        'PO2010-1842', 'SO2010-1851', 'Or2010-370', 'SO2010-1850',
#        'SR2010-639', 'R2010-640', 'SO2010-2640', 'SO2010-3049',
#        'O2010-3644', 'SO2010-3655', 'R2010-753',
#        'Case of Gary Kamen v. City of Chicago.', 'O2010-4213',
#        'O2010-6148', 'O2010-6918', 'O2010-6919', 'O2010-6113',
#        'O2010-5922', 'SO2010-7086; O2010-6824', 'A2011-56', 'O2011-5737',
#        'Or2011-929', 'O2011-5505', 'A2011-176', 'SO2011-9743',
#        'O2011-9744', 'SO2011-9778', 'SO2011-6726', 'SO2011-9742',
#        'SO2012-582', 'O2012-53', 'Or2012-182', 'SO2012-1473', 'O2012-1342',
#        'Table Fioretti Amendment', 'Table Waguespack Substitute',
#        'SO2012-1366', 'O2012-3337', 'SO2011-8844', 'SO2012-4489',
#        'O2012-6569', 'O2012-7239', 'O2012-7234', 'O2012-7254',
#        'SO2012-7113(v1)', 'SO2012-7112(v1)', 'O2012-7405', 'SO2012-7782',
#        'O2013-1606', 'O2013-1633', 'O2013-1640', 'O2013-1588',
#        'SO2012-8291', 'SO2013-4087', 'SO2012-5127', 'O2013-1678',
#        'A2013-92', 'SO2013-5384', 'O2013-28', 'O2013-5698', 'R2013-759',
#        'R2013-1104', 'SR2013-1103', 'R2013-1102', 'O2013-9185',
#        'SO2013-6160', 'O2014-500', 'O2014-560', 'SO2014-69', 'SO2014-869',
#        'SO2014-1282', 'SO2014-1521', 'O2014-2454', 'SO2014-2504',
#        'SO2014-1943', 'SO2014-3397', 'SO2014-836', 'SO2014-1367',
#        'SO2014-7247', 'O2013-7761', 'O2013-9188', 'O2014-4176',
#        'Or2014-455', 'O2014-8677', 'SO2014-6997', 'SO2014-8755',
#        'SO2014-8757', 'SO2014-9200', 'O2014-8960', 'O2014-8816',
#        'O2014-9680', 'O2014-8095', 'SO2015-4194', 'O2015-4685',
#        'SO2015-4701', 'O2015-5438', 'O2015-6123', 'SO2015-6215',
#        'O2015-5964', 'SO2015-6371', 'SO2015-6372', 'O2015-7390',
#        'SO2015-7403', 'O2015-7398', 'SO2015-7989', 'SO2015-6360',
#        'O2015-8054', 'O2015-8174', 'O2015-7191', 'SO2015-4229',
#        'Or2016-40', 'O2016-467', 'O2015-8241', 'SO2013-2478', 'SO2016-105',
#        'O2015-8498', 'O2015-6430', 'O2016-1599', 'A2016-15', 'O2016-2590',
#        'SO2016-4219', 'SO2016-4370', 'Or2016-327', 'Or2016-328',
#        'O2016-3928', 'O2016-3973', 'O2016-5111', 'SO2016-1729',
#        'SO2016-7090', 'O2016-5603', 'Or2016-436', 'O2016-5951',
#        'O2016-5592', 'O2016-6083', 'R2016-544', 'R2016-545', 'SO2016-9123',
#        'Or2016-677', 'Or2016-678', 'Or2016-679', 'O2016-9126',
#        'O2016-8676', 'Or2017-7', 'SR2016-978', 'SO2017-171', 'SO2016-8627',
#        'O2017-695', 'O2017-234', 'Or2017-52', 'Or2017-54', 'SO2016-8426',
#        'O2017-110', 'O2017-912'], dtype=object)

# %%
Counter(df_records.Record)
# Out:
# Counter({'A2006-103': 50,
#          'A2008-2': 50,
#          'A2011-176': 50,
#          'A2011-56': 50,
#          'A2013-92': 50,
#          'A2016-15': 50,
#          'ADJOURN#1': 50,
#          'ADJOURN#2': 50,
#          'Case of Gary Kamen v. City of Chicago.': 50,
#          'F2006-230': 50,
#          'FL2006-14': 50,
#          'O2006-4519': 50,
#          'O2006-4522': 50,
#          'O2006-4891': 50,
#          'O2006-4893': 50,
#          'O2006-4894': 50,
#          'O2006-5187': 50,
#          'O2007-1402': 50,
#          'O2007-3106': 50,
#          'O2007-5503': 50,
#          'O2008-2041': 50,
#          'O2008-538': 50,
#          'O2008-6774': 50,
#          'O2008-6775': 100,
#          'O2008-6776': 100,
#          'O2008-6777': 50,
#          'O2008-6778': 100,
#          'O2008-6782': 50,
#          'O2008-7304': 50,
#          'O2009-2415': 50,
#          'O2009-6223': 50,
#          'O2009-6224': 50,
#          'O2009-6230': 50,
#          'O2010-3644': 50,
#          'O2010-4213': 150,
#          'O2010-5922': 50,
#          'O2010-6113': 50,
#          'O2010-6148': 50,
#          'O2010-6918': 50,
#          'O2010-6919': 50,
#          'O2011-5505': 50,
#          'O2011-5737': 50,
#          'O2011-9744': 50,
#          'O2012-1342': 50,
#          'O2012-3337': 50,
#          'O2012-53': 50,
#          'O2012-6569': 50,
#          'O2012-7234': 50,
#          'O2012-7239': 50,
#          'O2012-7254': 50,
#          'O2012-7405': 50,
#          'O2013-1588': 50,
#          'O2013-1606': 50,
#          'O2013-1633': 50,
#          'O2013-1640': 50,
#          'O2013-1678': 50,
#          'O2013-28': 50,
#          'O2013-5698': 50,
#          'O2013-7761': 50,
#          'O2013-9185': 50,
#          'O2013-9188': 50,
#          'O2014-2454': 50,
#          'O2014-4176': 50,
#          'O2014-500': 50,
#          'O2014-560': 50,
#          'O2014-8095': 50,
#          'O2014-8677': 50,
#          'O2014-8816': 50,
#          'O2014-8960': 50,
#          'O2014-9680': 50,
#          'O2015-4685': 50,
#          'O2015-5438': 50,
#          'O2015-5964': 50,
#          'O2015-6123': 50,
#          'O2015-6430': 50,
#          'O2015-7191': 50,
#          'O2015-7390': 50,
#          'O2015-7398': 50,
#          'O2015-8054': 50,
#          'O2015-8174': 50,
#          'O2015-8241': 50,
#          'O2015-8498': 50,
#          'O2016-1599': 50,
#          'O2016-2590': 50,
#          'O2016-3928': 50,
#          'O2016-3973': 50,
#          'O2016-467': 50,
#          'O2016-5111': 50,
#          'O2016-5592': 50,
#          'O2016-5603': 50,
#          'O2016-5951': 50,
#          'O2016-6083': 50,
#          'O2016-8676': 50,
#          'O2016-9126': 50,
#          'O2017-110': 50,
#          'O2017-234': 50,
#          'O2017-695': 50,
#          'O2017-912': 50,
#          'OR2006-1552': 50,
#          'OR2007-1009': 50,
#          'Or2009-1': 50,
#          'Or2010-370': 50,
#          'Or2011-929': 50,
#          'Or2012-182': 50,
#          'Or2014-455': 50,
#          'Or2016-327': 50,
#          'Or2016-328': 50,
#          'Or2016-40': 50,
#          'Or2016-436': 50,
#          'Or2016-677': 50,
#          'Or2016-678': 50,
#          'Or2016-679': 50,
#          'Or2017-52': 50,
#          'Or2017-54': 50,
#          'Or2017-7': 50,
#          'PO2009-4114: Motion to Re-refer': 50,
#          'PO2009-4114: Motion to lay on table': 50,
#          'PO2010-1842': 50,
#          'R2007-1058': 50,
#          'R2009-1210': 50,
#          'R2010-640': 50,
#          'R2010-753': 50,
#          'R2013-1102': 50,
#          'R2013-1104': 50,
#          'R2013-759': 50,
#          'R2016-544': 50,
#          'R2016-545': 50,
#          'S02007-464': 50,
#          'S02008-2623': 50,
#          'SO2006-2971': 50,
#          'SO2006-3086': 50,
#          'SO2006-3936': 50,
#          'SO2006-3966': 50,
#          'SO2006-5062': 50,
#          'SO2007-3954': 50,
#          'SO2007-5794': 50,
#          'SO2007-5799': 50,
#          'SO2007-5800': 50,
#          'SO2007-5801': 50,
#          'SO2007-5802': 50,
#          'SO2008-4302': 50,
#          'SO2008-4315': 50,
#          'SO2008-537': 50,
#          'SO2008-6777': 50,
#          'SO2009-1115': 50,
#          'SO2009-2414': 50,
#          'SO2009-3410': 50,
#          'SO2009-5542': 50,
#          'SO2009-5597': 50,
#          'SO2010-163': 50,
#          'SO2010-1850': 50,
#          'SO2010-1851': 50,
#          'SO2010-2640': 50,
#          'SO2010-3049': 50,
#          'SO2010-3655': 50,
#          'SO2010-7086; O2010-6824': 50,
#          'SO2011-6726': 50,
#          'SO2011-8844': 50,
#          'SO2011-9742': 50,
#          'SO2011-9743': 50,
#          'SO2011-9778': 50,
#          'SO2012-1366': 50,
#          'SO2012-1473': 50,
#          'SO2012-4489': 100,
#          'SO2012-5127': 50,
#          'SO2012-582': 50,
#          'SO2012-7112(v1)': 50,
#          'SO2012-7113(v1)': 50,
#          'SO2012-7782': 50,
#          'SO2012-8291': 50,
#          'SO2013-2478': 50,
#          'SO2013-4087': 50,
#          'SO2013-5384': 50,
#          'SO2013-6160': 50,
#          'SO2014-1282': 50,
#          'SO2014-1367': 50,
#          'SO2014-1521': 50,
#          'SO2014-1943': 50,
#          'SO2014-2504': 50,
#          'SO2014-3397': 50,
#          'SO2014-69': 50,
#          'SO2014-6997': 50,
#          'SO2014-7247': 50,
#          'SO2014-836': 50,
#          'SO2014-869': 50,
#          'SO2014-8755': 50,
#          'SO2014-8757': 50,
#          'SO2014-9200': 50,
#          'SO2015-4194': 50,
#          'SO2015-4229': 50,
#          'SO2015-4701': 50,
#          'SO2015-6215': 50,
#          'SO2015-6360': 50,
#          'SO2015-6371': 50,
#          'SO2015-6372': 50,
#          'SO2015-7403': 50,
#          'SO2015-7989': 50,
#          'SO2016-105': 50,
#          'SO2016-1729': 50,
#          'SO2016-4219': 50,
#          'SO2016-4370': 50,
#          'SO2016-7090': 50,
#          'SO2016-8426': 50,
#          'SO2016-8627': 50,
#          'SO2016-9123': 50,
#          'SO2017-171': 50,
#          'SR2010-639': 50,
#          'SR2013-1103': 50,
#          'SR2016-978': 50,
#          'Table Fioretti Amendment': 50,
#          'Table Waguespack Substitute': 50})

# %%
df_records[df_records.Record == 'O2010-4213'].Date.unique()
# Out:
# array(['2010-10-06', '2010-11-03', '2011-01-13'], dtype=object)

# %%
read_date('2012-01-18')
# Out:
# ['Attendance and Divided Roll Call                                     Close',
#  'Vote',
#  'Attendance for the January 18, 2012 Meeting of the Chicago City',
#  'Council',
#  'Present - Aldermen Moreno, Fioretti, Dowell, Burns, Hairston, Sawyer, Jackson,',
#  'Harris, Beale, Pope, Balcer, Cárdenas, Quinn, Burke, Foulkes, Thompson,',
#  "Thomas, Lane, O'Shea, Cochran, Brookins, Muñoz, Zalewski, Chandler, Solis,",
#  'Maldonado, Burnett, Ervin, Graham, Reboyras, Suarez, Waguespack, Mell, Austin,',
#  "Colón, Sposato, Mitts, Cullerton, Laurino, P. O'Connor, Reilly, Smith, Tunney,",
#  '.',
#  'Arena, Cappleman, Pawar, Osterman, Moore, Silverstein -- 49',
#  'Absent -- Alderman M. O’Connor-- 1',
#  'Divided Roll Call Vote January 18, 2012 Meeting of the Chicago City',
#  'Council',
#  'There was five divided roll call votes for the January 18, 2012 meeting of the',
#  'Chicago City Council.',
#  'SO2011-9743: Amendment of Sections 2-84-053 and 10-36-110 of Municipal',
#  'Code to Authorize Execution of Agreements with Public and Private Entities',
#  'Regarding Planning, Security and Logistics Related to Hosting North Atlantic',
#  'Treaty Organization and Group of Eight Summits in Chicago During Spring',
#  '2012.(Click here for entire text of legislation)',
#  'O2011-9774: Amendment of Titles 4, 10 and 17 of Municipal Code to Regulate',
#  'Heliport Operations in Chicago. ( Click here for entire text of legislation)',
#  'O2011-9778: Amendment of Chapters 2-112, 9-48, 9-112 and 9-114 of Municipal',
#  'Code Regarding Taxicab and Chauffeur Regulations. (',
#  'Click here for entire text of',
#  'legislation)',
#  'O2011-6726: Amendment of Chapters 4-4 and 4-60 of Municipal Code to',
#  'Further Regulate Provisions for Suspension or Revocation of Business Licenses',
#  'Due to Illegal Activities on Business Premises. (Click here for entire text of',
#  'legislation)',
#  'O2011-9742: Amendment of Chapters 7-12, 8-32, 9-76, 9-108 and 10-8 of Municipal',
#  'Code to Further Regulate Parades, Athletic Events and Public Assemblies. ( Click here for',
#  'entire text of legislation )',
#  'Key: Y=yes  |  N=no  |  A=absent  |  NV=not voting  |  V=Vacant',
#  'E= Excused for voting under provisions of Rule 14 of City of Chicago Rules of',
#  'Order and Proceedings.',
#  "The issue and it's respective vote, as follows:",
#  'Issue:                          SO2011- O2011- SO2011- SO2011- SO2011-',
#  '9743      9744      9778       6726       9742',
#  '1st Ward: Proco Joe Moreno         Y         Y         Y          Y          Y',
#  '2nd Ward: Robert Fioretti          N         Y         Y          Y          N',
#  '3rd Ward: Pat Dowell    Y      Y      Y      Y       Y',
#  '4th Ward: William Burns N      Y      Y      Y       N',
#  '5th Ward: Leslie HairstonN     Y      Y      Y       N',
#  '6th Ward: Roderick SawyerY     Y      Y      Y       Y',
#  '7th Ward: Sandy Jackson N      Y      Y      Y       Y',
#  '8th Ward: Michelle HarrisY     Y      Y      Y       Y',
#  '9th Ward: Anthony Beale Y      Y      Y      Y       Y',
#  '10th Ward: John A. Pope Y      Y      Y      Y       Y',
#  '11th Ward: James A. BalcerY    Y      Y      Y       Y',
#  '12th Ward: George A.    Y      Y      Y      Y       Y',
#  'Cárdenas',
#  '13th Ward: Marty Quinn  Y      Y      Y      Y       Y',
#  '14th Ward: Edward M. BurkeY    Y      Y      Y       Y',
#  '15th Ward: Toni Foulkes Y      Y      Y      Y       Y',
#  '16th Ward: Joann ThompsonNV    Y      Y      Y       Y',
#  '17th Ward: Latasha R. ThomasY  Y      Y      Y       Y',
#  '18th Ward: Lona Lane    Y      Y      Y      Y       Y',
#  "19th Ward: Matthew O'SheaNV    Y      Y      Y       Y",
#  '20th Ward: Willie CochranY     Y      Y      Y       Y',
#  '21st Ward: Howard Brookins Jr.YY      Y      Y       Y',
#  '22nd Ward: Ricardo MuñozY      Y      Y      Y       Y',
#  '23rd Ward: Michael R. ZalewskiYY      Y      Y       Y',
#  '24th Ward: Michael ChandlerY   Y      Y      Y       Y',
#  '25th Ward: Daniel S. SolisY    Y      Y      Y       Y',
#  '26th Ward: Roberto MaldonadoY  Y      Y      Y       Y',
#  '27th Ward: Walter Burnett, Jr.YY      Y      Y       Y',
#  '28th Ward: Jason C. ErvinY     Y      Y      Y       Y',
#  '29th Ward: Deborah L. GrahamY  Y      Y      Y       Y',
#  '30th Ward: Ariel E. ReboyrasY  Y      Y      Y       Y',
#  '31st Ward: Regner Ray SuarezY  Y      Y      Y       Y',
#  '32nd Ward: Scott WaguespackY   Y      Y      Y       Y',
#  '33rd Ward: Richard F. MellY    Y      Y      Y       Y',
#  '34th Ward: Carrie M. AustinY   Y      Y      Y       Y',
#  '35th Ward: Rey Colón    Y      Y      Y      Y       Y',
#  '36th Ward: Nicholas SposatoN   Y      Y      Y       N',
#  '37th Ward: Emma Mitts   Y      Y      Y      Y       Y',
#  '38th Ward: Timothy M.   Y      Y      Y      Y       Y',
#  'Cullerton',
#  '39th Ward: Margaret LaurinoY   Y      Y      Y       Y',
#  "40th Ward: Patrick J. O'ConnorYY      Y      Y       Y",
#  "41st Ward: Mary O'ConnorA      A      A      A       A",
#  '42nd Ward: Brendan ReillyY     N      Y      Y       Y',
#  '43rd Ward: Michele SmithNV     Y      Y      Y       Y',
#  '44th Ward: Thomas TunneyY      Y      Y      Y       Y',
#  '45th Ward: John Arena   Y      Y      N      N       Y',
#  '46th Ward: James CapplemanY    Y      Y      Y       Y',
#  '47th Ward: Ameya Pawar  Y      Y      Y      Y       Y',
#  '48th Ward: Harry OstermanY     Y      Y      Y       Y',
#  '49th Ward: Joe Moore    Y      Y      Y      Y       Y',
#  '50th Ward: Debra SilversteinY  Y      Y      Y       Y',
#  'Totals:',
#  'Yes:                    41    48     48      48     45',
#  'No:                     5      1      1      1       4',
#  'Excused:                0      0      0      0       0',
#  'Not voting:             3      0      0      0       0',
#  'Absent:                 1      1      1      1       1',
#  'Vacant:                 0      0      0      0       0',
#  '']

# %%
df_titles[df_titles.Title.str.contains('Amendment of Title 2, Chapter 8 of Municipal Code Concerning')].Title.values
# Out:
# array([ 'Amendment of Title 2, Chapter 8 of Municipal Code Concerning Redistricting of City Wards'], dtype=object)

# %%
df_titles[df_titles.Title == '']
# Out:
#            Date                               Record Title
# 52   2009-10-07  PO2009-4114: Motion to lay on table
# 53   2009-10-07      PO2009-4114: Motion to Re-refer
# 74   2010-11-03                           O2010-4213
# 80   2011-01-13                           O2010-4213
# 88   2012-01-18                           O2011-9744
# 89   2012-01-18                          SO2011-9778
# 90   2012-01-18                          SO2011-6726
# 91   2012-01-18                          SO2011-9742
# 93   2012-02-15                             O2012-53
# 97   2012-04-24             Table Fioretti Amendment
# 98   2012-04-24          Table Waguespack Substitute
# 103  2012-09-12                          SO2012-4489
# 109  2012-11-15                      SO2012-7112(v1)

# %%
df_titles[df_titles.Date == '2011-09-08'].Title.values
# Out:
# array([ 'An order authorizing to enter into and execute a settlement order for Connie Coleman, as special administrator of the Estate of John Coleman Jr. Deceased v. City of Chicago, et al.',
#        'An ordinance to amend Chapter 7-36 of the Municipal Code of Chicago regarding crib bumper pads.'], dtype=object)

# %%
df_titles.Title.values
# Out:
# array([ 'Amendment of Title 2, Chapter 8, Section 041 of Municipal Code of Chicago by Establishment of New Aldermanic Compensation Schedule. ( entire text of legislation )',
#        'Amendment of Title 4 of Municipal Code of Chicago by Creation of New Chapter 404 Entitled "Large Retailers".',
#        'Failed To Pass  -- Amendment of Title 4, Chapter 208 of Municipal Code of Chicago by Addition of New Section 077 Requiring Notification of Guests Concerning Work Stoppage.',
#        'Rejection of Bids for purchase of City-Owned property at 6238 South Kimbark Avenue.',
#        'Mayoral Veto of Ordinance adding New Chapter 4-404 of Municipal Code of Chicago entitled "Large Retailers".',
#        'Appointment of Mr. Peter M. Holsten as Member of Uptown Commission (Special Service Area Number 34).',
#        'Amendment of Title 4, Chapter 144 and Title 8, Chapter 24, Section 040 of Municipal Code of Chicago to Prohibit Sale, Transfer or Discharging of Replica Air Guns within City of Chicago.',
#        'Authorization of Intergovernmental agreement with Chicago Housing Authority for Procurement and Management of Consulting Services for Le Claire Courts.',
#        'Authorization for Execution of Intergovermental agreement with Chicago Park District and Lease Agreement with Loop parking, L.L.C. For Chicago Downtown public parking system.',
#        'Authorization for Corporation Counsel to enter into and execute settlement agreement regarding case of Erik Kittler V. City of Chicago, Detective Steven Buglio, Detective Wayne Bunch, Detective Judy Castellanos, Detective Steven Konow, Sergeant Sergio Rajkovich, Detective Thurman Royster, Detective Leonard Rolston, John Stout, unknown Chicago Police Employees and Assistant Cook County States Attorney Kent Sinso, in his individual capacity.',
#        'Approval of Tax Increment Financing Redevelopment plan for LaSalle Central Redevelopment Project Area.',
#        'Designation of La Salle Central Redevelopment project area as Tax Increment Financing District.',
#        'Adoption of Tax Increment Allocation Financing for La Salle Central Redevelopment project area.',
#        'Amendment of Titles 2, 9, and 13 of Municipal Code of Chicago concerning various Revenue related matters.',
#        'Tax Levy Ordinance.', 'Revenue Fines and Fees.',
#        'C.D.B.G. Ordinance, As Amended.',
#        'Annual Appropiation Ordinance, As Amended.',
#        'Departmental Organization.',
#        'Amendment of Title 17, Chapter 17, Section 0104-A(4) of Municipal Code of Chicago (Chicago Zoning Ordinance) by modifying Definition of Adult Entertainment Cabaret.',
#        "Authorization for execution of agreements with various private and Municipal entities in conjunction with City of Chicago's bid application to host 2016 Olympics.",
#        "Authorization for execution of various Concessionaire Lease Agreements at O'Hare and Midway International Airports.",
#        'Rules Suspended  -- Expression of support for passage of Illinois Senate Bill 1751 concerning uninsured and unlicensed Immigrants. ( legislation)',
#        'Amendment of Title 2, Chapter 92 of Municipal Code of Chicago by further Regulation of Public Art Program.',
#        'Authorization for Corporation Counsel to enter into and execute settlement agreement regarding Case of Stacy Walker-Talbert V. Duane Blackman, Aaron Long and The City of Chicago .',
#        'Amendment of Title 2 of Municipal Code of Chicago by addition of New Chapter 26 establishing Office of Compliance.',
#        'Amendment of various Titles of Municipal Code of Chicago concerning City Organization and Management.',
#        '2008 Annual Appropriation Ordinance, as amended.',
#        'Amendment of Title 3, Chapter 33, Section 070 and Title 17, Chapter 13, Subsection 0103 of Municipal Code of Chicago by increasing filing fee for Real Property Transfer Declaration.',
#        'Amendment of Title 11, Chapter 12, Sections 530 and 531 of Municipal Code of Chicago by Establishment of application fee for issuance of Certificates of payments to condominiums for Water and Sewer Assessments.',
#        'Amendment of Titles 2, 3, 4, 7, 9, 11, 13, and 17 of Municipal Code of Chicago concerning Revenue related matters.',
#        'Auhthorization for Tax Levy on all Taxable Property within City of Chicago for Year 2008.',
#        'Appointment of Jody P. Weis as Superintendent of Department of Police.',
#        'Amendment of Title 3, Chapter 33, Sections 030 and 060 of Municipal Code of Chicago regarding imposition of Supplemental Real Estate Transfer Tax for Benefit of and Authorization for Execution of Intergovernmental agreement with Chicago Transit Authority.',
#        'Amendment of Title 3, Chapter 33 of Municipal Code of Chicago by addition of new Section 160 establishing certain requirements for Use of Chicago Real Property Transfer Tax Funds by Chicago-Area Public Transit Systems.',
#        'Amendment of Title 7, Chapter 39 of Municipal Code of Chicago by deletion of Sections  to 001 allow and sale 005 of foie gras by food establishments.',
#        '1',
#        'Amendment of Title 4, Chapter 92, Sections 050 of Municipal Code of Chicago to Further Restrict Issuance of Massage Establishment Licenses.',
#        'Amendment of Title 2, Chapter 152, Section 072 of Municipal Code of Chicago Regarding Qualified Domestic Partners Eligibility for City Benefits.',
#        'Amendment of Various Titles of Municipal Code of Chicago Concerning City Organization and Management.',
#        'for entire text of legislation)',
#        'Submission of Final Statement of Objectives and Projected Use of Funds or Community Development Block Grant Year XXXV, as Amended.',
#        'Amendment of Title 1, 3, 4, 9, 10 and 11 of Municipal Code of Chicago Concerning Various Revenue-Related Matters. ( of legislation)',
#        'Authorization for Tax Levy on All Taxable Property within City of Chicago for Year 2009.',
#        '5',
#        'Order authorizing the execution of a settlement agreement in the case of Laura Salazar, Independent Administrator of the Estate of Juan Salazar, deceased v. City of Chicago and Officer Rafael Balbontin.',
#        'Amendment of Sections 4-280-370 and -790 of Municipal Code concerning funding for the Chicago Access Corporation.',
#        'Execution of Intergovernmental Agreement with Illinois Environmental Protection Agency Regarding Procedures for Refuse of Soil and Rubble Excavated Within and for Use by City of Chicago.',
#        'Amendment of Sections 4-260-150 and 7-28-331 of Municipal Code concerning Commercial Refuse Container Permits and Regulations.',
#        'Committee on License: Substitute Ordinance to Amend Title 4-268 of the Municipal Code of Chicago Regarding Street Performers.',
#        'Substitute Ordinance amending regulations concerning elevators.',
#        'Alderman Carothers MOTION to RE-REFER Amendment of Title 4-208 concerning Work Stoppage to the Committee on Finance.',
#        '', '',
#        'Reaffirmation of Support for Dream Act and Call on United States Department of Homeland Security to Halt Removal of Rigoberto Padilla and Other Immigrant Students While Act Is Under Consideration.',
#        '2010 Annual Appropriations ordinance, as amended.Click ( here for entire text of legislation)',
#        'Authorization for Year 2010 Tax Levy on all taxable property within City of Chicago.',
#        'Amendment of Chapter 2-32 of Municipal Code by addition of new Section 6267 establishing property tax relief program for qualified homeowners.',
#        'Amendement of Title 2-156 Prohibiting the Hiring of Aldermanic Family Members.',
#        'Motion to adjourn', 'Motion to adjourn',
#        'Execution of Intergovernmental Agreements with Chicago Board of Education for School Improvements.',
#        'Issuance of General Obligation Refunding Bonds, Series 2007A-K for School Purposes.',
#        'Execution of Settlement Agreement Re: Thomas Dunn, Denny Robinson, and Veronica Imperial, on Behalf of Themselves and Similarly Situated, and Leonard Kimball, Individually, v. City of Chicago.',
#        'Amendment of Municipal Code by Creation of New Chapter 2-55 and Authorizing Other Municipal Code Amendments regarding the Office of Inspector General.',
#        "Amended Resolution Urging the City of Chicago, All City Departments, and City's Sister Agencies to Prospectively Boycott Goods and Services Manufactured, Produced, and Provided by Arizona Based Companies In Protest of Arizona Law SB1070.",
#        "Resolution urging the Chicago Council's Joint Committee on Finance and Committee on Human Relations to conduct hearings denouncing Arizona Law .",
#        'An Ord. Regarding New Standards and Redistricting the Location of Massage Parlors.',
#        'An Ordinance Authorizing the Establishment of a Vacant Property Purchase Program to be known as the Vacant REO Purchase Program.',
#        'Amendment of Titles 2, 4 and 8 of Municipal Code Regarding .',
#        'A Substitute Ordinance Authorizing the Execution of an Amendment to the Redevelopment Agreement with W2005 CMK Realty, LLC.',
#        'A Resolution Urging the City to Consent to and Approve the Transfer of RCN Chicago to Yankee Cable Acquisition, LLC. legislation)',
#        'Case of Gary Kamen v. City of Chicago.',
#        'Amendment of Chapter 8-4 of Municipal Code by Adding New Section 8-4-087 Regarding Chronic Illegal Activity Premises. text of legislation)',
#        '',
#        'Amendment of Various Titles of Municipal Code Concerning City Organization and Management.',
#        '2011 Annual Appropriation Ordinance, as Amended.',
#        'Submission of Final Statement of Objectives and Projected Use of',
#        'Amendment of Titles 2, 3 and 9 of Municipal Code Concerning Various Revenue-Related Matters.',
#        'Year 2011 Tax Levy On All Taxable Property Within City of Chicago.',
#        '',
#        'Motion Tabled --Amendment of Title 2-45 of Municipal Code by Adding New Section 115 To Establish Affordable Housing Goals.',
#        'Appointment of Commissioner of the Department of Human Relations . Soo Choi Amending Chapter 2-74-050 - relates to Human Resources Rules',
#        "Concession Agreement for Terminal 5 at Chicago O'Hare Int'l Airport.",
#        'An order authorizing to enter into and execute a settlement order for Connie Coleman, as special administrator of the Estate of John Coleman Jr. Deceased v. City of Chicago, et al.',
#        'An ordinance to amend Chapter 7-36 of the Municipal Code of Chicago regarding crib bumper pads.',
#        'Appointment of Faisal Khan as Legislative Inspector General for . City Council',
#        'Amendment of Sections 2-84-053 and 10-36-110 of Municipal Code to Authorize Execution of Agreements with Public and Private Entities Regarding Planning, Security and Logistics Related to Hosting North Atlantic Treaty Organization and Group of Eight Summits in Chicago During Spring 2012.',
#        '', '', '', '',
#        'Amendment of Title 2, Chapter 8 of Municipal Code Concerning Redistricting of City Wards',
#        '',
#        'Settlement agreement regarding case of Jose Lopez v The City of Chicago; Chicago Police Officers Robert Gliwa, Star No. 20526, James R. Sanchez, Star No. 20336; Adrian Garcia, Star No. 20517; Michael Pietryla, Star No. 21209; and T. Flaherty, Star No. 20942, cited as 08 L 7549',
#        'A substitute ordinance amending Section 2-14-140 of the Municipal Code by establishing Children’s Safety Zones',
#        'Agreement with Alta Bicycle Sharing, Inc. for operation of bicycle sharing system',
#        '', '',
#        'A substitute ordinance establishing the Chicago Infrastructure Trust',
#        'Amendment of Chapters 2-112 and 8-16 of the Municipal Code to regulate Tanning Facilities.',
#        'Amendment of Chapter 8-4 of Municipal Code by adding new Section 365 regarding possession of cannabis',
#        'Amendment of Titles 2, 4, 7, 9, 10 and 17 of Municipal Code regarding mobile food vehicles.',
#        '',
#        'Redevelopment agreement with Shops & Lofts at 47 for acquisition, construction, rehabilitation and equipping of affordable multi-family housing project.',
#        'Authorization to enter into and execute a redevelopment agreement with DeVry, Inc.',
#        'Authorization to enter into and execute a redevelopment agreement with Ravenswood Station, LLC.',
#        'Authorization to enter into and execute a redevelopment agreement with River Point, LLC.',
#        '2013 Annual Appropriation Ordinance, as Amended.', '',
#        'Levy of 2013 Real Estate Taxes.',
#        'Amendment of Title 17 of Municipal Code and Execution of Agreement to Establish “City Digital Signs” and City Digital Network',
#        'Amendment of Chapter 4-236 of Municipal Code regarding parking garage tax',
#        "Outdoor advertising concession lease and license agreement with JCDecaux Airport, Inc., d.b.a. JCDecaux Airport Chicago LLC at Chicago O'Hare and Midway International Airports",
#        "Indoor advertising concession lease and license agreements with Clear Channel Outdoor, Inc. d.b.a. Clear Channel Airports at Chicago O'Hare and Midway International Airports",
#        'Zoning Reclassification App No. 17692 at 2245 W Pershing Rd.',
#        'Amendment of Section 11-12-540 of Municipal Code regarding exemption from payment of water rates for certain not-for-profit organizations',
#        'Settlement agreement and associated amendment to Chicago Metered Parking System Concession Agreement',
#        'Amending the Municipal Code of Chicago by adding Chapter 5-14, Protecting Tenants at Foreclosures',
#        'Canopy(s) for New Parie Hotel',
#        'Appointment of Deborah L. Mell as Alderman of 33rd Ward.',
#        'Amendment of Title 18 of Municipal Code by adding new Chapter 18-14 regarding building energy use benchmarking',
#        'Zoning Reclassification App No. 17648 at 2501 N Elston Ave',
#        'Redistribution of surplus funds from Tax Increment Financing (TIF) districts',
#        'Submission of public question to Chicago voters regarding election of members of Chicago Board of Education',
#        'Resolution initiating and authorizing a non-binding referendum on whether the City of Chicago should increase taxi rates',
#        'Initiating and authorizing a non-binding referendum on whether to ban high capacity magazines with more than 15 rounds',
#        'Initiating and authorizing a non-binding referendum to ban the possession of a concealed firearm in any establishment licensed to serve alcohol',
#        'Amendment of Chapter 6-64 of the Municipal Code of Chicago concerning sale of flavored tobacco products',
#        'Amendment of Chapters 4-64 and 7-32 of the Municipal Code of Chicago regarding e-cigarettes',
#        'City of Chicago General Obligation and Refunding Bonds, Series 2014 and amend Chapter 2-32 of Municipal Code of Chicago concerning debt management policies',
#        'Issuance of Chicago Midway Airport Revenue Bonds, Series 2014',
#        'Chicago Five Year Housing Plan for Years 2014-2018, as amended',
#        'Intergovernmental agreement with Metropolitan Pier and Exposition Authority regarding construction and rehabilitation of property at 300 E Cermak Rd',
#        'Amendment of Municipal Code Chapter 4-384 by adding new Section 015 to regulate retail sale of dogs, cats or rabbits',
#        'Amendment of Municipal Code Chapter 11-4 by adding Article XXIII to prohibit retail establishments from providing customers with plastic carryout bags from waste stream',
#        'Amendment of Municipal Code Section 4-60-130 to further regulate hours of operation for alcoholic liquor establishments',
#        'Amendment of Municipal Code Chapters 7-28, 10-8, 13-20, 13-96, 17-12 and 17-17 to further regulate provisions governing installation of various types of illuminated signs',
#        'Amendment of Municipal Code Chapters 17-2, 17-3, 17-4, 17-5, 17-6, 17-9 and 17-17 regarding coke and coal bulk material facilities',
#        'Amendment of Municipal Code Titles 2, 3, 4 and 9 to regulate pedicabs',
#        'Zoning Reclassification App No. 17944 at 2101-2143 S. Indiana Ave, 205-319 E. 21st St, 204-334 E. Cermak Rd and 2134-2142 S. Calumet Ave',
#        'Amendment of Municipal Code Titles 2, 3 and 9 concerning establishment of transportation network provider license',
#        'Amendment of Municipal Code of Chicago amending Chapter 7-28 regarding commercial refuse containers',
#        'Amendment of Municipal Code Chapter 2-156 regarding duty and power of Board of Ethics to review campaign finance filing compliance of candidates for City office',
#        'Amendment of Municipal Code Titles 7 and 17 concerning medical cannabis',
#        'Zoning Reclassification Map Number 1-L at 400-420 North Laramie Ave and 5200-5214 West Kinzie St - App No. 18045',
#        'Jianqing Klyzek v. City of Chicago, Frank Messina, Gerald DiPasquale, Sandra Stoppa, Daniel Sako, Michael Iglesias, Sergio Flores, Duran Puhar, Tyrone Jackson, Eugene Sledge and Kenneth Corcoran, Cited as 14 C 3547',
#        'Authorizing the Commissioner of the Department of Family and Support Services to enter into a loan agreement and contract with IFF Pay for Success I, LLC',
#        'Amendment of Municipal Code Title 5 by adding Chapter 5-15 entitled Single-Room Occupancy and Residential Hotel Preservation Ordinance',
#        'Annual Appropriation Ordinance Year 2015, as amended',
#        'CDBG Year XLI Ordinance, as amended',
#        'Amendment of Municipal Code Titles 1, 2, 3, 4, 7, 9, 10, 11, 13 and 17 concerning various department functions and duties (2015 Management Ordinance)',
#        'Amendment of Municipal Code Titles 3 and 4 concerning various taxes, charges and fees (2015 Revenue Ordinance)',
#        'Property tax levy for Year 2015',
#        'Amendment of Municipal Code Sections 2-25-050, 2-92-320, 2-92-610, 4-4-320 and adding new Chapter 1-24 regarding Chicago minimum wage',
#        'Vote to lay on Table, Motion to Discharge Committee on Transportation and Public Way regarding Amendment of Municipal Code Title 9 by adding new Sections 9-100-160, 9-101-070 and 9-102-050 to allow review and sunset provisions for traffic violations',
#        'Issuance of 2015 General Obligation Bonds and associated authority to select dissemination agent',
#        'An ordinance regarding sundry amendments and corrections to the City of Chicago Ethics Ordinance',
#        'An ordinance regarding sundry amendments and corrections to the City of Chicago Ethics Ordinance',
#        'A communication recommending an ordinance to issue City of Chicago General Obligation Bonds, Series 2015',
#        'A communication recommending an ordinance to issue City of Chicago General Obligation Bonds, Series 2015',
#        'A substitute ordinance authorizing the issuance of City of Chicago Wastewater Transmission Revenueonds, Project and Refunding Series B 2015',
#        'Intergovernmental agreement with Chicago Housing Authority (CHA) for additional police services',
#        'Annual Appropriation Ordinance Year 2016, as amended, and associated Annual Appropriation Ordinance 2015 supplemental appropriation',
#        '2016 Community Development Block Grant (CDBG) Ordinance, as Amended',
#        '2016 Management Ordinance', '2016 Revenue Ordinance',
#        '2015 -- 2018 Property Tax Levies',
#        'Amendment of Municipal Code Titles 9 and 10 by further regulating transportation network services and public chauffeur licenses',
#        'Zoning Reclassification Map No. 4-E at 1410 Museum Campus Dr, 458 E 18th St, 600 E Waldron Dr, 1559 S Lake Shore Dr and properties with address ranges of 414-508 E 18th St, 415-509 E 18th St, 1600-1800 S Museum Campus Dr and 1800-1930 S Burnham Harbor Dr - App No. 18482 (Lucas Museum of Narrative Art)',
#        'Support of Class 7(c) tax incentive for property at 825 W 47th St',
#        'Sale of City-owned property at 5709 South State Street',
#        'Amendment of Municipal Code Section 9-68-020(c) to increase maximum allowable number of one-day parking permits available for purchase for each residential address per month',
#        'Amendment of Municipal Code Chapters 2-56 and 2-156, repeal of Chapter 2-55 and amendment of 2016 Annual Appropriation Ordinance concerning Office of Inspector General and Board of Ethics',
#        'Settlement agreement regarding United States Department of Justice allegations against Chicago Police Department for National Origin Discrimination before 2011',
#        'Negotiated sale and conveyance of City-owned property to The University of Chicago and The University of Chicago Charter School Corporation',
#        'Amendment of Municipal Code Section 17-9-0129 concerning medical cannabis dispensing organizations and cultivation centers',
#        'Zoning Reclassification Map Nos. 11-F and 11-G at 4400-4458 N Clarendon Ave and 4401-4415 N Clarendon Ave - App No. 17707',
#        'Amend Title 3 and Chapter 4-64 of the Municipal Code of Chicago concerning a tax on non-cigarette tobacco products and associated tobacco-regulated regulations.',
#        'Zoning Reclassification Map No. 12-I at 2833-2927 W 47th St and 4701- 4733 S Richmond St - App No. 18607',
#        'Zoning Reclassification Map No. 7-H at 2820-2996 N Clybourn Ave, 2000-2144 W Diversey Pkwy, 2007-2141 W Diversey Pkwy, 2601-2953 N Leavitt Ave, 2800-2888 N Leavitt Ave, 2601-2769 N Hoyne Ave, 2600- 2768 N Hoyne Ave, 2600-2800 N Damen Ave and 2201-2223 W Oakdale Ave - App No. 18535',
#        'Amendment to Section 2-102-075 of the Municipal Code of Chicago regarding special assessment allowances.',
#        'Appointment of Richard C. Ford II as member of the Chicago Emergency Telephone System Board',
#        'Amendment of Municipal Code Chapter 2-84 regarding Police Board powers and duties and appointment of Superintendent of Police',
#        'A substitute ordinance approving a redevelopment agreement with Montrose-Clarendon Park',
#        'A substitute ordinance approving a redevelopment agreement with Montrose-Clarendon Partners LLC for construction residential units, retail space and parking facilities',
#        'Panzy Edwards, as Special Administrator of Estate of Dakota Bright v. P.O.B. Ternand, Individually, and City of Chicago, cited as 12 L 13429',
#        'Levail Smith v. Officer Timothy Manning, Officer Hector Davila, Sergeant Allen Finley, and City of Chicago, cited as 15 C 5898',
#        'Amendment to Phase I cargo facility lease with Aero Chicago LLC at Chicago O’Hare International Airport',
#        'Amendment of Municipal Code Section 2-160-070 to allow gender identity access to public accommodations',
#        'Amendment of Municipal Code Titles 3, 4, and 17 concerning hotel accommodations, short term residential rental intermediaries, share housing, lodging types',
#        'Amendment of Municipal Code Title 9 concerning public chauffeur licenses and transportation network services',
#        'A substitute ordinance concerning the authority tamo end Title 3 of the Municipal Code of Chicago by adding Chap80 ter 3en-titled “Chicago Water and Sewer Tax”',
#        'An ordinance concerning the authority to approve fee waivers and the refunding of fees paid by the Chicago Public Schools',
#        'Rachel Brown, as Independent Administrator of the Estate of Eugene Ratliff, deceased v. City of Chicago, Ricardo Sanchez, and Dorian Williams, cited as 13 L 13704',
#        'An ordinance authorizing the Commissioner of the Department of Planning and Development to enter into and execute an Intergovernmental Agreement with the Chicago Board of Education regarding TIF assistance for New South Loop Elementary school',
#        'An ordinance authorizing the issuance of Chicago O’Hare International Airport Passenger Facility Charge Revenue Refunding Bonds, 2016A and Chicago O’Hare International Airport Passenger Facility Charge Revenue Refunding Bonds, 2016B',
#        'An ordinance authorizing the issuance of Chicago O’Hare International Airport General Airport Senior Lien Revenue Bonds, Series 2016A and 2016B',
#        'Support of Class 6(b) tax incentive for property at 4237 W. Lurie Pl',
#        'Support of Class 6(b) tax incentive for property at 717 S. Desplaines St',
#        'Amendment of Chapters 3-42 and 4-64 of the Municipal Code of Chicago',
#        'Settlement agreement regarding Kaine Godfrey, Gail Mtharorris, Tamala Watkins, Monica Dentley and Carla Lloyd, individually and on behalf of all others similarly situated; and Kimberly Bailey, Mildred Brown, Lynette Collins, Lonetta Curtis, Evelyn Davis, Laura Henry, Lynette Moore, Erica D. Sanders, Gwen Stevenson, Yolanda Webb, Sheila Williams, Danita Williams, and Letreona Woods, individually v. City of Chicago, cited as 12 C 8601',
#        'Settlement agreement regarding Linda Chatman, individually and as Independent Executor of the Estate of Cedrick Chatman, Deceased v. Kevin Fry and City of Chicago, cited as 13 C 5697',
#        'Settlement agreement regarding Matthew Colyer and Gloria Pinex, Administrator of the Estate of Darius Pinex v. City of Chicago, Officer Raoul Mosqueda and former Officer Gildardo Sierra, cited as 12 CV 4855',
#        'Annual Appropriation Ordinance Year 2017 amendment within Corporate Fund No. 100 for establishment of Legal Protection Fund',
#        'Denial of a demolition fee waiver for the Jobs for the Future Training Center located at 3837 South Wabash',
#        'Cassandra Miller, as Special Administrator of the Estate of Willie Miller, Deceased v. City of Chicago and Officer Scott Leck, cited as 11 L 3250',
#        "Affirmation of City of Chicago's support to honor and protect rights of all residents regardless of race, ethnicity, country of origin, religion, age, immigration status, criminal record, sexual orientation and gender identity",
#        'Annual Appropriation Ordinance Year 2017 amendment within Corporation Fund No. 100',
#        'A substitute ordinance to amend Chapters 4-6, 4-13, and 4-14 of the Municipal Code of Chicago regarding legal duties of bed-and-breakfast establishment, vacation rental and shared housing unit licensees',
#        'Concessions Redevelopment and Management Lease Agreement with Midway Partnership LLC',
#        'Intergovernmental Agreement with Illinois State Toll Highway Authority regarding Elgin O’Hare Western Access Project',
#        'Hugo Holmes v. City of Chicago and Officer Michelle Acosta, cited as 09 C 2481',
#        'Carmen Carrillo v. City of Chicago and Alan Roberts cited as 13 L 14188',
#        'Amendment of Municipal Code Chapter 2-8 regarding Honorary Street signs designations',
#        'Honorary street designation as "Oscar Lopez Rivera Way"',
#        'Amendment of Municipal Code Section 9-64-205 and 9-64-206 regarding metered parking during Wrigley Field Stadium events'], dtype=object)
